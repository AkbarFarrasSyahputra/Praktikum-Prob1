# %%
import pandas as pd
df= pd.read_clipboard()

# %%
df
# Out:
#          Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0       Damar      L      2024           172                60       Tangerang
# 1      Fathir      L      2024           177                60       Tangerang
# 2      Naufal      L      2024           160                10          Grogol
# 3      Shalwa      P      2024           159                10          Cideng
# 4    Silviana      P      2024           160                10          Grogol
# 5      Sheila      P      2024           155                30          Jaktim
# 6       Ifiki      L      2024           168                60          Bekasi
# 7        Yuda      L      2024           175                20   Tanjung Duren
# 8   Kurniawan      L      2024           160                40     Kebun Jeruk
# 9        Arif      L      2024           167                30          Grogol
# 10      Bagas      L      2024           175                30          Tomang

# %%
rata_tinggi=df['Tinggi Badan'].mean()
rata_tinggi
# Out:
# 166.1818181818182

# %%
print(df.dtypes)
# Out:
# Nama                object
# Gender              object
# Angkatan             int64
# Tinggi Badan         int64
# Waktu Perjalanan     int64
# Wilayah Tinggal     object
# dtype: object

# %%
df['Angkatan'] = df['Angkatan'].astype(str)

# %%
print(df.dtypes)
# Out:
# Nama                object
# Gender              object
# Angkatan            object
# Tinggi Badan         int64
# Waktu Perjalanan     int64
# Wilayah Tinggal     object
# dtype: object

# %%
import pandas as pd

df = pd.read_csv("C:/Users/farra/OneDrive/Dokumen/akbarrr.csv", sep=';')

df
# Out:
#          Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0       Damar      L      2024           172                60       Tangerang
# 1      Fathir      L      2024           177                60       Tangerang
# 2      Naufal      L      2024           160                10          Grogol
# 3      Shalwa      P      2024           159                10          Cideng
# 4    Silviana      P      2024           160                10          Grogol
# 5      Sheila      P      2024           155                30          Jaktim
# 6       Ifiki      L      2024           168                60          Bekasi
# 7        Yuda      L      2024           175                20   Tanjung Duren
# 8   Kurniawan      L      2024           160                40     Kebun Jeruk
# 9        Arif      L      2024           167                30          Grogol
# 10      Bagas      L      2024           175                30          Tomang
# ...

# %%
df = pd.read_excel("C:/Users/farra/OneDrive/Dokumen/akbarr.xlsx")
df
# Out:
#          Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0       Damar      L      2024           172                60       Tangerang
# 1      Fathir      L      2024           177                60       Tangerang
# 2      Naufal      L      2024           160                10          Grogol
# 3      Shalwa      P      2024           159                10          Cideng
# 4    Silviana      P      2024           160                10          Grogol
# 5      Sheila      P      2024           155                30          Jaktim
# 6       Ifiki      L      2024           168                60          Bekasi
# 7        Yuda      L      2024           175                20   Tanjung Duren
# 8   Kurniawan      L      2024           160                40     Kebun Jeruk
# 9        Arif      L      2024           167                30          Grogol
# 10      Bagas      L      2024           175                30          Tomang
# ...
